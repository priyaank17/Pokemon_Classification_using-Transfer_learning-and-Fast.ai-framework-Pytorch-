# %% [markdown]
# <a href="https://colab.research.google.com/github/priyaank17/Pokemon_Classification_using-Transfer_learning-and-Fast.ai-framework-Pytorch-/blob/master/Pokemon_Classification_using_Resnets50_and_Transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  We will build a pokemon image classifier from scratch using Resnet architecture and Fast ai flowwork.

# %% [markdown]
# # Download Dataset

# %% [markdown]
# # Initial Setings and Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163).

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# we set the batch size, Batch size means how many images to load into the main memory of your system for one training cycle.
#
# Maximum batch_size is limited by the memory that your system has -- main memory in case of CPU and GPU memory if you are using the GPU

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# Setting up the dataset path

# %%
from pathlib import Path
dataset_path = Path.cwd() / 'pokemon-image-dataset'
dataset_path
# Out:
# PosixPath('/content/pokemon-image-dataset')

# %%
for currentFile in dataset_path.iterdir():
    print(currentFile)
# Out:
# /content/pokemon-image-dataset/squirtle
# /content/pokemon-image-dataset/pikachu
# /content/pokemon-image-dataset/charmander
# /content/pokemon-image-dataset/.git
# /content/pokemon-image-dataset/README.md
# /content/pokemon-image-dataset/bulbasaur

# %%
classes = ['pikachu','charmander','squirtle','bulbasaur']

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path=dataset_path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['bulbasaur', 'charmander', 'pikachu', 'squirtle']

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['bulbasaur', 'charmander', 'pikachu', 'squirtle'], 4, 484, 121)

# %%
data.show_batch(rows=3, figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.528002</td>
#       <td>0.415664</td>
#       <td>0.132231</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.793165</td>
#       <td>0.059904</td>
#       <td>0.024793</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.499919</td>
#       <td>0.034514</td>
#       <td>0.008264</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.355928</td>
#       <td>0.030177</td>
#       <td>0.008264</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-1')

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='15' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.33% [8/15 02:53<02:31]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
# If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.020148</td>
#       <td>0.027584</td>
#       <td>0.008264</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.016202</td>
#       <td>0.009601</td>
#       <td>0.008264</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %% [markdown]
# That's a pretty accurate model!

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
interp.plot_confusion_matrix()

# %%
interp.most_confused(min_val=1)
# Out:
# [('pikachu', 'charmander', 1)]

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
interp.plot_top_losses(9, figsize=(15,11))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %% [markdown]
# ## Exporting model and testing it

# %%
output_folder = os.path.join(os.getcwd(), 'outputs')
model_name = 'poke_predictor_resnet34'   
pickled_model_name = f'{model_name}.pkl'
os.makedirs(output_folder, exist_ok=True)

learn.export(os.path.join(output_folder, pickled_model_name))

# %% [markdown]
# This will create a pickle file  in the directory where we were working that contains everything we need to deploy our model

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(dataset_path/'squirtle/00000004.jpg')
img
# Out:
# Image (3, 360, 480)

# %%
learn = load_learner(dataset_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-5def4ee11229> in <module>()
# ----> 1 learn = load_learner(dataset_path)
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load_learner(path, file, test, tfm_y, **db_kwargs)
#     619     "Load a `Learner` object saved with `export_state` in `path/file` with empty data, optionally add `test` and load on `cpu`. `file` can be file-like (file or buffer)"
#     620     source = Path(path)/file if is_pathlike(file) else file
# --> 621     state = torch.load(source, map_location='cpu') if defaults.device == torch.device('cpu') else torch.load(source)
#     622     model = state.pop('model')
#     623     src = LabelLists.load_state(path, state.pop('data'))
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category tensor(3)
